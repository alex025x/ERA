# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# # Data Collection Notebook
#
# ## Objectives
# * Load local employee retention dataset
# * Inspect the data and save it under outputs/datasets/collection
# * Prepare initial insights for further analysis
#
# ## Inputs
# * Local dataset file - hr_employee_churn.data.csv
#
# ## Output
# * Raw data saved to `outputs/datasets/collection/employee_retention_processed.csv`

# %% [markdown]
# ---

# %%
import sys
print("Current Python path:", sys.executable)
# Out:
# Current Python path: /home/gitpod/.pyenv/versions/3.8.18/bin/python

# %%
import subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])
# Out:
# ...
# 0

# %%
import os
import pandas as pd

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * Get our current working directory

# %%
current_dir = os.getcwd()
print("Current working directory:", current_dir)
# Out:
# Current working directory: /workspace/ERA/jupyter_notebooks

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Kaggle data

# %% [markdown]
# ### First, import required libraries and load our dataset

# %%
import pandas as pd

df = pd.read_csv("/workspace/ERA/inputs/datasets/hr_employee_churn_data.csv")
print("First few rows of our dataset:")
df.head()
# Out:
# First few rows of our dataset:
#    empid  satisfaction_level  last_evaluation  number_project  \
# 0      1                0.38             0.53               2
# 1      2                0.80             0.86               5
# 2      3                0.11             0.88               7
# 3      4                0.72             0.87               5
# 4      5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  salary  left
# 0                      0     low     1
# 1                      0  medium     1
# 2                      0  medium     1
# 3                      0     low     1
# ...

# %% [markdown]
# Get detailed information about our dataset structure

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  4998 non-null   int64
#  1   satisfaction_level     4998 non-null   float64
#  2   last_evaluation        4998 non-null   float64
#  3   number_project         4998 non-null   int64
#  4   average_montly_hours   4998 non-null   int64
#  5   time_spend_company     4998 non-null   int64
#  6   Work_accident          4998 non-null   int64
#  7   promotion_last_5years  4998 non-null   int64
#  8   salary                 4998 non-null   object
#  9   left                   4998 non-null   int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 390.6+ KB

# %% [markdown]
# Check for any null or missing values in our columns

# %%
print("Checking for missing values in each column:")
df.isnull().sum()
# Out:
# Checking for missing values in each column:
# empid                    0
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %% [markdown]
# Look for any duplicate records in our dataset

# %%
print("Checking for duplicate records:")
df[df.duplicated(subset=None)]
# Out:
# Checking for duplicate records:
# Empty DataFrame
# Columns: [empid, satisfaction_level, last_evaluation, number_project, average_montly_hours, time_spend_company, Work_accident, promotion_last_5years, salary, left]
# Index: []

# %% [markdown]
# Examine unique values in categorical columns and columns with few unique values

# %%
print("Analyzing unique values in columns:")
for col in df:
    if df[col].dtypes=='object':
        print(f"\n{col} - Unique values:", df[col].unique())
    elif df[col].unique().size < 11:
        print(f"\n{col} - Number of unique values:", df[col].unique().size)
# Out:
# Analyzing unique values in columns:
#
# number_project - Number of unique values: 6
#
# time_spend_company - Number of unique values: 5
#
# Work_accident - Number of unique values: 2
#
# promotion_last_5years - Number of unique values: 2
#
# salary - Unique values: ['low' 'medium' 'high']
#
# left - Number of unique values: 2

# %% [markdown]
# # Push files to Repo

# %%
try:
    os.makedirs(name='outputs/datasets/collection')
    print("Successfully created outputs/datasets/collection folder")
except Exception as e:
    print(e)

# Save processed dataset
df.to_csv(f"outputs/datasets/collection/employee_retention_processed.csv", index=False)
print("Dataset successfully saved to outputs/datasets/collection/employee_retention_processed.csv")
# Out:
# Successfully created outputs/datasets/collection folder
# Dataset successfully saved to outputs/datasets/collection/employee_retention_processed.csv
