# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save it as raw data.
# * Inspect the data and save it under outputs/datasets/collection
# * Prepare initial insights for further analysis
#
# ## Inputs
#
# *   Kaggle JSON file - the authentication token.
#
# ## Output

# %% [markdown]
# ### Output
# - Raw data saved to `outputs/datasets/collection/TelcoCustomerChurn.csv`.

# %% [markdown]
# ---

# %%
import sys
print("Current Python path:", sys.executable)

# %%
import subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])

# %%
import os
import pandas as pd

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * Get our current working directory

# %%
current_dir = os.getcwd()
print("Current working directory:", current_dir)

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Kaggle data

# %%
file_path = "/workspace/ERA/inputs/datasets/raw/hr_employee_churn.data.csv"

# %%
# Load and validate the dataset
try:
    df = pd.read_csv(file_path)
    print("\n=== Data Loading Success ===")
    print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns")
    
    print("\n=== Basic Data Quality Checks ===")
    
    # 1. Check for missing values
    print("\nMissing values in each column:")
    missing_values = df.isnull().sum()
    print(missing_values[missing_values > 0] if missing_values.any() > 0 else "No missing values found")
    
    # 2. Check for duplicates
    duplicate_count = df.duplicated().sum()
    print(f"\nNumber of duplicate rows: {duplicate_count}")
    
    # 3. Examine data types and unique values
    print("\nColumn information:")
    for column in df.columns:
        unique_values = df[column].nunique()
        print(f"\n{column}:")
        print(f"- Data type: {df[column].dtype}")
        print(f"- Unique values: {unique_values}")
        # For categorical columns or columns with few unique values, show the values
        if df[column].dtype == 'object' or unique_values < 10:
            print(f"- Values: {sorted(df[column].unique())}")
            
    # 4. Basic statistical summary for numerical columns
    print("\n=== Statistical Summary for Numerical Columns ===")
    print(df.describe())
    
except FileNotFoundError:
    print(f"Error: Cannot find the file at {file_path}")
    print("Please verify the exact file path and name")
except Exception as e:
    print(f"An error occurred while processing the data: {str(e)}")

# %% [markdown]
# # Push files to Repo

# %%
import os
try:
  os.makedirs(name='outputs/datasets/collection') # create outputs/datasets/collection folder
except Exception as e:
  print(e)

df.to_csv(f"outputs/datasets/collection/TelcoCustomerChurn.csv",index=False)
