# %% [markdown]
# # Employee Retention Study Notebook

# %% [markdown]
# ## Objectives
# * Analyze relationships between employee attributes and retention
# * Create correlation and PPS analysis for feature selection
# * Visualize key patterns in employee retention data
#
# ## Inputs
# * Processed dataset from previous notebook: `outputs/datasets/collection/employee_retention_processed.csv`
#
# ## Output
# * Correlation and PPS heatmaps showing key retention factors

# %% [markdown]
# ---

# %% [markdown]
# # Setting up enviroment and load data

# %%
# Import required libraries
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ppscore as pps

# Check and set working directory
current_dir = os.getcwd()
os.chdir(os.path.dirname(current_dir))
print("Working directory set to:", os.getcwd())

# Load processed dataset
df = pd.read_csv("outputs/datasets/collection/employee_retention_processed.csv")
print(f"Dataset loaded with {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# Working directory set to: /workspace/ERA
# Dataset loaded with 4998 rows and 10 columns

# %% [markdown]
# # Prepare data for Analysis

# %%
# Create one-hot encoded version of our dataset
# This converts categorical variables into numeric format for correlation analysis
df_encoded = pd.get_dummies(df, drop_first=True)
print("Encoded dataset shape:", df_encoded.shape)
# Out:
# Encoded dataset shape: (4998, 11)

# %% [markdown]
# ---

# %% [markdown]
# #
