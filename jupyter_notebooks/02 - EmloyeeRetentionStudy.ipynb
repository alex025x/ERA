# %% [markdown]
# # Employee Retention Study Notebook

# %% [markdown]
# ## Objectives
# * Analyze relationships between employee attributes and retention
# * Create correlation and PPS analysis for feature selection
# * Visualize key patterns in employee retention data
#
# ## Inputs
# * Processed dataset from previous notebook: `outputs/datasets/collection/employee_retention_processed.csv`
#
# ## Output
# * Correlation and PPS heatmaps showing key retention factors

# %% [markdown]
# ---

# %% [markdown]
# # Setting up enviroment and load data

# %%
# Import required libraries
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ppscore as pps

# First, check our current directory and print it
current_dir = os.getcwd()
print("Current directory:", current_dir)

# Define the file path for our processed dataset
file_path = "/workspace/ERA/outputs/datasets/collection/employee_retention_processed.csv"

# Verify file exists
if os.path.exists(file_path):
    print(f"Found the file at: {file_path}")
    # Load the dataset
    df = pd.read_csv(file_path)
    print(f"Successfully loaded dataset with shape: {df.shape}")
else:
    print(f"File not found at: {file_path}")

# %% [markdown]
# # Prepare data for Analysis

# %%
# Create one-hot encoded version of dataset
# This converts categorical variables into numeric format for correlation analysis
df_encoded = pd.get_dummies(df, drop_first=True)
print("Encoded dataset shape:", df_encoded.shape)

# %% [markdown]
# ---

# %% [markdown]
# # Define Analysis Function

# %%
def create_correlation_heatmap(df, method='pearson', threshold=0.3, figsize=(12,10), font_size=10):
    """
    Create and display a correlation heatmap
    
    Parameters:
        df: DataFrame to analyze
        method: correlation method ('pearson' or 'spearman')
        threshold: minimum correlation value to display
        figsize: size of the plot
        font_size: size of annotation text
    """
    # Calculate correlation matrix
    corr_matrix = df.corr(method=method)
    
    # Create mask for upper triangle and low correlations
    mask = np.zeros_like(corr_matrix, dtype=bool)
    mask[np.triu_indices_from(mask)] = True
    mask[abs(corr_matrix) < threshold] = True
    
    # Create heatmap
    plt.figure(figsize=figsize)
    sns.heatmap(corr_matrix, 
                mask=mask,
                annot=True,
                cmap='viridis',
                annot_kws={"size": font_size},
                linewidth=0.5)
    plt.title(f'{method.capitalize()} Correlation Heatmap')
    plt.show()

def calculate_pps_matrix(df, threshold=0.2, figsize=(12,10), font_size=10):
    """
    Calculate and display Power Predictive Score matrix
    
    Parameters:
        df: DataFrame to analyze
        threshold: minimum PPS value to display
        figsize: size of the plot
        font_size: size of annotation text
    """
    # Calculate PPS matrix
    pps_matrix = pps.matrix(df)
    pps_matrix_pivot = pps_matrix.pivot(columns='x', index='y', values='ppscore')
    
    # Create mask for low PPS scores
    mask = pps_matrix_pivot < threshold
    
    # Create heatmap
    plt.figure(figsize=figsize)
    sns.heatmap(pps_matrix_pivot,
                mask=mask,
                annot=True,
                cmap='rocket_r',
                annot_kws={"size": font_size},
                linewidth=0.5)
    plt.title('Power Predictive Score Heatmap')
    plt.show()
    
    return pps_matrix

# %% [markdown]
# # Running the Analysis

# %%
print("Generating Pearson correlation heatmap...")
create_correlation_heatmap(df_encoded, method='pearson', threshold=0.3)

print("\nGenerating Spearman correlation heatmap...")
create_correlation_heatmap(df_encoded, method='spearman', threshold=0.3)

print("\nCalculating Power Predictive Scores...")
pps_matrix = calculate_pps_matrix(df_encoded, threshold=0.2)

# %% [markdown]
# ## Visualization of categorical Relationships

# %%
# Parallel categories plot for key variables
import plotly.express as px

columns_for_parallel = ['satisfaction_level', 'last_evaluation', 'salary', 'left']
df_parallel = df[columns_for_parallel]

fig = px.parallel_categories(df_parallel, color="left")
fig.show()

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion
#
# The correlation and PPS heatmaps revealed strong relationships between employee turnover and satisfaction levels, workload, and evaluations. The parallel plot demonstrated how combinations of these factors influence departures.
#
# The heatmaps showed:
# - Red areas indicate stronger correlations/relationships
# - Satisfaction level had highest predictive power
# - Work hours and project load showed significant impact

# %% [markdown]
# #
